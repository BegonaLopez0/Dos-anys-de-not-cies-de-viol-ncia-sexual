# %%
import warnings
warnings.filterwarnings('ignore')
from pyemd import emd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score,  precision_recall_curve
from gensim.models.keyedvectors import KeyedVectors
from nltk.stem.snowball import SpanishStemmer
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from datetime import datetime, timedelta
import lxml.etree as ET
import seaborn as sns
import pandas as pd
import numpy as np
import regex as re
import itertools
import unidecode
import spacy
import html
import os
import networkx as nx

# %%
NEWS_PATH = 'data/news/'

# %%
def listdir_checked(path, unwanted = ['.DS_Store']):
    '''
    Discard unwanted files or directories when listing the elements in a given path
    '''
    return (f for f in os.listdir(path) if f not in unwanted)


def normalize_string(to_normalize, encoded = False):
    '''
    Normalize text given a string
    '''
    text = str(to_normalize).lower()  # lowering text
    if encoded: 
        text = ' '.join([html.unescape(term) for term in text.split()])
    text = unidecode.unidecode(text)

    text = re.sub(r'[^\w\s]', '', text)  # removing all the punctuations
    last_text = text.split()  # tokenize the text

    # remove stopwords
    stopwords_set = set(stopwords.words("spanish"))
    stopwords_set = stopwords_set.union(set(["name"]))
    
    last_text = ' '.join([x for x in last_text if (x not in stopwords_set)])
    return last_text


def classify_entities(doc):
    '''
    Given an nlp doc, returns:
    * A dictonary with the entities grouped by type: 'PER', 'LOC', 'ORG' and 'MISC'
    * A list with all the entities
    '''
    classif_dict = {}
    classif_list = []
    for ent in doc.ents:
        try:
            classif_list.append(ent)
            classif_dict[ent.label_].append(ent)
        except:
            classif_dict[ent.label_] = [ent]
    # Check that the dict has all the keys
    for key in ['PER', 'LOC', 'ORG', 'MISC']:
        if key not in classif_dict.keys():
            classif_dict[key] = None

    return classif_dict, classif_list


def create_articles_dictionary(NEWS_PATH):
    '''
    Import articles information.
    Articles are stored in directories in the NEWS_PATH.
    '''
    data = {}               # keys: media, value: list of dictionaries with info about the news articles of the given media
    unique_urls = []        # list to store unique urls to discard repeated ones
    repeated_data = {}      # store repeated articles following the same format as 'data' dictionary


    for year in listdir_checked(NEWS_PATH):
            for month in listdir_checked(NEWS_PATH + '/' + year):
                    for file in listdir_checked(NEWS_PATH + '/' + year + '/' + month):
                        try:
                            full_path = NEWS_PATH + '/' + year + '/' + month + '/' + file
                            # Read xml file - info stored following NewsML-G2 format
                            root = ET.parse(full_path).getroot()
                            # Parse news
                            media = file.rsplit('_', 1)[0]
                            # Check repeated urls
                            url = root.findall(".//infoSource")[0].get("uri")
                            str_date = root.findall('.//contentMeta')[0].find('contentCreated').text[:10]
                            info = {
                                'id': file.split(':')[-1].replace('.xml', ''),
                                'media': media,
                                'publication_date': datetime.strptime(str_date, '%Y-%m-%d'),
                                'title': normalize_string(root.findall('.//itemRef')[0].find('title').text, encoded = True),
                                'headline': normalize_string(root.findall(".//itemRef")[0].find('description').text.strip(), encoded = True),
                                'article': normalize_string(root.findall('.//itemRef')[1].find('description').text.strip(), encoded = True),                'url': url
                            }

                            if url not in unique_urls:
                                unique_urls.append(url)
                                try:
                                    data[media].append(info)
                                except:
                                    data[media] = [info]

                            else:
                                try:
                                    repeated_data[media].append(info)
                                except:
                                    repeated_data[media] = [info]
                        except:
                            pass
                        
    return data, repeated_data


def load_elements(data):
    '''
    Load auxiliary variables:
    * mapping_keys - dict with key: tweet id -> value: absolute position to manage matrices
    * mapping_tweets - dict with key: value -> tweet_is: absolute position to manage matrices
    '''
    mapping_keys = {}  # key: tweet id -> value: absolute position in all_entities
    mapping_tweets = {}  # key: value -> tweet_id: absolute position in all_entities
    counter = 0

    for media, new in data.items():
        print('------ MEDIA:', media)
        for element in new:
            mapping_keys[element['id']] = counter
            mapping_tweets[counter] = element['id']

            counter += 1
            
    return mapping_keys, mapping_tweets


def cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets):
    '''
    Compute cosine similarity of f-idf vectors
    '''
    
    # GET NEWS ARTICLES
    print('---GETTING NEWS')
    N = len(mapping_keys)
    articles = [None] * N
    for media, new in data.items():
        for element in new:
            try:
                pos = mapping_keys[element['id']]
                
                articles[pos] = normalize_string(element['title'] + ' ' + 
                                                 element['headline'] + ' ' + 
                                                 element['article'])
            except:
                pass

    # COMPUTE TF-IDF
    # Stem
    print('---STEM')
    stemmer = SpanishStemmer(ignore_stopwords=False)
    for i, article in enumerate(articles):
        try:
            articles[i] = str([stemmer.stem(word) for word in article.split()])
        except:
            articles[i] = 'null'
            pass
        
    # Compute tf-idf
    print('---COMPUTE TF-IDF')  
    stopwords_spanish = [word.encode().decode('utf-8') for word in stopwords.words('spanish')] # Remove stopwords
    vectorizer = TfidfVectorizer(stop_words=stopwords_spanish)
    X = vectorizer.fit_transform(articles)

    # COMPUTE COSINE SIMILARITY MATRIX
    print('---COMPUTE COSINE SIMILARITY MATRIX')
    cosine_sim_matrix = np.zeros(shape=(N, N))
    for row in pairs_df.iterrows():
        
        i = mapping_keys[str(id_A)]
        j = mapping_keys[str(id_B)]

        similarity = cosine_similarity(X[i], X[j])[0][0]
        cosine_sim_matrix[i, j] = 1-similarity
        cosine_sim_matrix[j, i] = 1-similarity

    return cosine_sim_matrix


def add_similarity_column(pairs_df, mapping_keys, similarity_matrix, column_name):
    '''
    Arguments:
     * pairs_df
         - pd.DataFrame
         - contains pairs of tweet_ids --> column names: [tweet_id_A, tweet_id_B]
     * mapping_keys
         - dictionary
         - key: tweet_id, value: position
     * similarity_matrix
         - np.matrix
         - symmetrical matrix with the similarity between tweets
     * column_name
         - string
         - name of the new column to be added in pairs_df
    '''
    similarity_pairs = []               # Create list with the same order as pairs_df
    for i, row in pairs_df.iterrows():
        tid_A = row['tweet_id_A']       # Obtain tweet id
        tid_B = row['tweet_id_B']       # Get the position of each article in the matrix
        pos_A = mapping_keys[tid_A]
        pos_B = mapping_keys[tid_B]
        similarity_pairs.append(similarity_matrix[pos_A, pos_B])             # Order similarity following pairs_df order
    pairs_df.insert(len(pairs_df.columns), column_name, similarity_pairs)   # Add new column
    return pairs_df

def componentes_conexas(G):
    '''
    Given a graph return a dictionary with the connected components
    '''
    
    def visita(v): 
        cc[v] = componente_actual 
        for u in G[v]:
            if u not in cc: 
                visita(u)
    cc = dict() 
    componente_actual = 0
    for v in G:
        if v not in cc:
            visita(v)
            componente_actual += 1
    return cc

# %% [markdown]
# # 1. Load Data

# %%
data, repeated_data = create_articles_dictionary(NEWS_PATH)

# %%
#CONSTRUCT A DATAFRAME WITH ALL THE ARTICLES AND THE INFORMATION NEEDED
articles_df = pd.DataFrame()

for media in data.keys():
    for new in data[media]:
        tweet_id = new['id']
        title = normalize_string(new['title'])
        headline = normalize_string(new['headline'])
        url = new['url']
        publication_date = new['publication_date']
        article = normalize_string(new['article'])
        
        articles_df = articles_df.append({'tweet_id': tweet_id, 'media': media, 'title': title, 
                                          'headline': headline, 'url': url, 'publication_date': publication_date,
                                          'article': article},
                                       ignore_index=True)

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14961 entries, 0 to 14960
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          14961 non-null  object
#  1   media             14961 non-null  object
#  2   title             14961 non-null  object
#  3   headline          14961 non-null  object
#  4   url               14961 non-null  object
#  5   publication_date  14961 non-null  datetime64[ns]
#  6   article           14961 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 818.3+ KB

# %%
mapping_keys, mapping_tweets = load_elements(data)
# Out:
# ------ MEDIA: 20m
# ------ MEDIA: okdiario
# ------ MEDIA: LaVanguardia
# ------ MEDIA: europapress
# ------ MEDIA: larazon_es
# ------ MEDIA: abc_es
# ------ MEDIA: elperiodico
# ------ MEDIA: elmundoes
# ------ MEDIA: publico_es
# ------ MEDIA: rtve
# ------ MEDIA: el_pais
# ------ MEDIA: La_SER
# ------ MEDIA: informativost5
# ------ MEDIA: ElHuffPost
# ------ MEDIA: voz_populi
# ------ MEDIA: COPE
# ------ MEDIA: elconfidencial
# ------ MEDIA: elespanolcom
# ------ MEDIA: eldiarioes
# ------ MEDIA: laSextaTV
# ------ MEDIA: OndaCero_es
# ------ MEDIA: noticias_cuatro
# ------ MEDIA: libertaddigital
# ------ MEDIA: EFEnoticias_ES

# %% [markdown]
# # 2. Determine parameters epsilon and T

# %%
#Select 40 random articles
k1_articles = articles_df.sample(n=40)
k1_articles
# Out:
#                   tweet_id           media  \
# 2548   1455856028008943617    LaVanguardia
# 5341   1435569864974950400          abc_es
# 850    1455837894640390149             20m
# 6843   1407043237240573954     elperiodico
# 6632   1375820879649767424     elperiodico
# 4330   1369400106227806217      larazon_es
# 3590   1489625954997927936     europapress
# 9431   1422675995312771080         el_pais
# 12194  1219616140919480322            COPE
# 1726   1509866552128155655             20m
# 12836  1364200838751793158  elconfidencial
# 12679  1220635156777775104  elconfidencial
# 9609   1498221606476394497         el_pais
# 726    1466716596387422208             20m
# 10285  1488414361504866307          La_SER
# 11971  1438408817453289472      voz_populi
# 12526  1494266886577610753            COPE
# 5772   1452794611311812610          abc_es
# 14038  1216179240133103618       laSextaTV
# 9000   1323690153882263553         el_pais
# 11496  1229678253973131264      ElHuffPost
# 5262   1272145513354268672          abc_es
# 838    1461337860179738634             20m
# 14570  1511388419359924233       laSextaTV
# 3209   1440460835093159936     europapress
# 5232   1276443835615326211          abc_es
# 2631   1350099156069736449    LaVanguardia
# 12060  1486743044309270528      voz_populi
# 2445   1247701144576700416    LaVanguardia
# 8433   1399389355043602433      publico_es
# 13137  1212806771833802752    elespanolcom
# 10138  1420689557427785733          La_SER
# 12892  1426570558573928452  elconfidencial
# 4926   1236101284387840000          abc_es
# 997    1359408004672720900             20m
# 12925  1405263679717666818  elconfidencial
# 8403   1459179139748007943      publico_es
# 10858  1457803339672875016  informativost5
# 13809  1501324383024922629      eldiarioes
# 3517   1445382012366426121     europapress
#
#                                                    title  \
# 2548    cree joven denuncio agresion parte menas invento
# 5341          joven trans denuncia agresion parte hombre
# 850    cree falsa denuncia supuesta agresion cuatro j...
# 6843                                  nino ahora triunfa
# 6632                   frente drama 3 violacion multiple
# 4330   traficante esclavos borracho columnista desata...
# 3590   prision provisional presuntamente violar mujer...
# 9431   pide renuncia gobernador democrata tras inform...
# 12194     hermanos evitaron violacion pensamos dos veces
# 1726   juez pide imputar existir indicios solidos enc...
# 12836       20 anos exedil pp agresion sexual dos presos
# 12679      provisional dos acusados violar joven 21 anos
# 9609   comisiones dudas victimas pederastia piden coo...
# 726    imperdonable haber romantizado violacion averg...
# 10285                                 importa privacidad
# 11971       juzga profesor acusado abusar cuatro alumnas
# 12526  cita declarar caso explotacion sexual menores ...
# 5772   agresor sexual viola mujer tres dias obtener l...
# 14038                 hombre agresion sexual tres abusos
# 9000   verdadero criminal asesino confiesa 14 muertes...
# 11496  boy eeuu declaran quiebra tras enfrentarse cie...
# 5262   menor 17 anos critico tras ser quemada supuest...
# 838                       trailer medio escandalo sexual
# 14570            hombre asesina cuchilladas nina 14 anos
# 3209      asegura juzga montaje policial agresion agente
# 5232   soldados colombianos aceptan cargos violacion ...
# 2631   estudiante millonario dia malvado violador ser...
# 12060              mienten serie mejora ficcion espanola
# 2445                   jugador estrella asesino convicto
# 8433   lname condena tres agresiones homofobas fin se...
# 13137  violacion tres hermanas sido horrible asi contado
# 10138                                 importa privacidad
# 12892           anos carcel escandalo sexual detras kpop
# 4926   detenidos prostitucion secuestro menores tutel...
# 997    agredido casa okupa violaron turnos pegaron or...
# 12925  jueza incoa diligencias denuncia presentada ag...
# 8403          voluntad investigar abusos sexuales pasado
# 10858  nina 4 anos rescatada relata secuestro mujer p...
# 13809            presenta ley europea violencia machista
# 3517   216000 menores sido victimas abusos parte sace...
#
#                                                 headline  \
# 2548   denunciante candidata 2015 declaro television ...
# 5341   lamenta escalada violencia colectivo lgtbi ins...
# 850         vicelehendakari consejero senalado miercoles
# 6843   personaje serie chico sexual avanza actor cant...
# 6632   cosas revolvian bastante estomago comenta actr...
# 4330   articulista tambien censurado normalizar cultu...
# 3590                                       not specified
# 9431   concluye raiz investigacion independiente acci...
# 12194  contado cope reaccionaron ver joven trataba ag...
# 1726        numero 15 pedido tsjcv impute vicepresidenta
# 12836  hechos ocurrieron 2017 concejal consistorio 20...
# 12679  dos hombres amigos hermano victima encontraron...
# 9609   auditoria cee coincide debate investigacion pu...
# 726    pelicula 2016 componia varias historias centra...
# 10285  acusado aprovechaba sesiones terapia ninas 12 ...
# 11971  juzga jueves profesor sexto primaria desempena...
# 12526  delegacion desplazara abril investigar cuestio...
# 5772   interno protagonizo incidente prision agosto i...
# 14038  agresor actuaba tras abordaba victimas espalda...
# 9000   coreano chunjae declaro culpable varios asesin...
# 11496  estima anos 40 pasado siglo mas 7800 personas ...
# 5262   joven habia conocido presunto agresor 45 anos ...
# 838      serie actriz bateria podra ver partir 2 febrero
# 14570  presunto asesino vecino mismo bloque menor sid...
# 3209                                       not specified
# 5232   juez municipal municipio ocurrieron hechos dec...
# 2631   mayor depredador sexual hombres historia 136 v...
# 12060  arranca mienten apacible manana habitantes meg...
# 2445   jugador estrella condenado cadena perpetua ase...
# 8433   agredidos operado domingo tras quedar herido a...
# 13137  jovenes conocieron presuntos agresores local c...
# 10138  investigacion inicio semanas atras tras consta...
# 12892  industria entretenimiento surcoreana envuelta ...
# 4926   hechos ocurrieron investigacion comenzo agosto...
# 997    dos jovenes detenidos violar hombre casa okupa...
# 12925  decision consiste tramite necesario previo ado...
# 8403   coordinado estudio abusos sexuales catolica ll...
# 10858  nina australiana 4 anos secuestrada rescatada ...
# 13809  norma propone penalizar violacion basada falta...
# 3517                                       not specified
#
#                                                      url publication_date  \
# 2548   https://www.lavanguardia.com/local/paisvasco/2...       2021-11-03
# 5341   https://www.abc.es/espana/comunidad-valenciana...       2021-09-08
# 850    https://www.20minutos.es/noticia/4877189/0/la-...       2021-11-03
# 6843   https://www.elperiodico.com/es/tele/20210619/m...       2021-06-19
# 6632   https://www.elperiodico.com/es/tele/20220308/a...       2022-03-08
# 4330   https://www.larazon.es/cultura/20210309/5hoqsw...       2021-03-09
# 3590   https://www.europapress.es/catalunya/noticia-p...       2022-02-04
# 9431   https://elpais.com/internacional/2021-08-03/el...       2021-08-03
# 12194  https://www.cope.es/emisoras/asturias/noticias...       2020-01-21
# 1726   https://www.20minutos.es/noticia/4979918/0/el-...       2022-04-01
# 12836  https://www.elconfidencial.com/espana/madrid/2...       2021-02-23
# 12679  https://www.elconfidencial.com/espana/andaluci...       2020-01-24
# 9609   https://elpais.com/sociedad/2022-02-28/tantas-...       2022-02-28
# 726    https://www.20minutos.es/cinemania/noticias/es...       2021-12-03
# 10285  https://cadenaser.com/2022/02/01/el-supremo-co...       2022-02-01
# 11971  https://www.vozpopuli.com/espana/profesor-prim...       2021-09-16
# 12526  https://www.cope.es/emisoras/illes-balears/bal...       2022-02-17
# 5772   https://www.abc.es/espana/abci-agresor-sexual-...       2021-10-25
# 14038  https://www.lasexta.com/noticias/sociedad/enca...       2020-01-11
# 9000   https://elpais.com/politica/2020/11/03/cronica...       2020-11-03
# 11496  https://www.huffingtonpost.es/entry/los-boy-sc...       2020-02-18
# 5262   https://www.abc.es/internacional/abci-menor-17...       2020-06-14
# 838    https://www.20minutos.es/cinemania/series/prim...       2021-11-18
# 14570  https://www.lasexta.com/noticias/sociedad/homb...       2022-04-05
# 3209   https://www.europapress.es/nacional/noticia-al...       2021-09-21
# 5232   https://www.abc.es/internacional/abci-siete-so...       2020-06-26
# 2631   https://www.lavanguardia.com/sucesos/20210115/...       2021-01-15
# 12060  https://www.vozpopuli.com/altavoz/cultura/todo...       2022-01-27
# 2445   https://www.lavanguardia.com/deportes/20200408...       2020-04-08
# 8433   https://www.publico.es/sociedad/observatori-l-...       2021-05-30
# 13137  https://www.elespanol.com/reportajes/20200102/...       2020-01-02
# 10138  https://cadenaser.com/emisora/2021/07/29/ser_m...       2021-07-29
# 12892  https://www.elconfidencial.com/mundo/2021-08-1...       2021-08-13
# 4926   https://www.abc.es/sociedad/abci-seis-detenido...       2020-03-07
# 997    https://www.20minutos.es/noticia/4577404/0/agr...       2021-02-09
# 12925  https://www.elconfidencial.com/espana/2021-06-...       2021-06-16
# 8403   https://www.publico.es/sociedad/josep-maria-ta...       2021-11-12
# 10858  https://www.telecinco.es/informativos/internac...       2021-11-08
# 13809  https://www.eldiario.es/sociedad/bruselas-pres...       2022-03-08
# 3517   https://www.europapress.es/sociedad/noticia-21...       2021-10-05
#
#                                                  article
# 2548   caso joven 30 anos supuestamente agredida barr...
# 5341   joven trans veintiun anos denunciado haber suf...
# 850    vicelehendakari consejero senalado miercoles e...
# 6843   netflix series programas television instituto ...
# 6632   serie atresmedia series programas television a...
# 4330   revisionismo hizo arrancar prohibir menores 7 ...
# 3590   girona 4 europa press 6 enviado prision provis...
# 9431   gobernador peso pesado cuyo nombre sonado cons...
# 12194  hermanos pensaron dos veces pasado domingo die...
# 1726   numero 15 pedido viernes tsjcv impute vicepres...
# 12836  pide 20 anos carcel exedil pp presunta agresio...
# 12679  numero 6 decretado ingreso prision provisional...
# 9609   victimas abusos sexuales reclaman investigacio...
# 726    pasado cinco anos estreno amor hace comedia er...
# 10285  sala penal confirmado condena 17 anos medio ca...
# 11971  juzga jueves profesor sexto primaria desempena...
# 12526  delegacion viajara investigar casos explotacio...
# 5772   carcel pasado dia 17 tras cumplir condena puls...
# 14038  funciones guardia decretado sabado prision pro...
# 9000   uniforme preso azul lunes chunjae confesado tr...
# 11496  boy of bsa mayores organizaciones juveniles de...
# 5262   joven rumana 17 anos ingresada grave quemadura...
# 838    paren rotativas serie 2022 fotos rodaje filtra...
# 14570  nina 14 anos sido asesinada cuchilladas bloque...
# 3209   madrid 21 europa press exsecretario diputado a...
# 5232   siete soldados acusados violar nina indigena p...
# 2631   nombre ficticio desperto aturdido encontraba d...
# 12060  arranca mienten apacible manana habitantes meg...
# 2445   pesar futbol americano lista deportes favorito...
# 8433   joven sido operado domingo tras quedar herido ...
# 13137  verano comenzo buscar piso instalarse capital ...
# 10138  aprome detuvieron pasado 23 julio hombre 29 an...
# 12892  marzo 2019 saltaba escandalo varias estrellas ...
# 4926   detenido seis hombres cinco presuntos autores ...
# 997    dos jovenes detenidos violar hombre casa okupa...
# 12925  juez instruccion numero 16 incoado diligencias...
# 8403   coordinado trabajo conjunto abusos sexuales ca...
# 10858  mas duro nina australiana 4 anos secuestrada r...
# 13809  violencia mujeres violencia domestica estan pr...
# 3517   menos 216000 menores sido victimas abusos part...

# %%
#Construct pairs of the articles
T = [10, 15, 30, 60]
cases_df = pd.DataFrame(columns=['tweet_id_A', 'article_A', 'url_A', 'tweet_id_B', 'article_B', 'url_B', 'vmdistance'])
epsilon = 0.50

pairs_df = pd.DataFrame()

for row in k1_articles.iterrows():
    for timeframe in T:
        tweet_id = row[1]['tweet_id']
        title = row[1]['title']
        headline = row[1]['headline']
        media = row[1]['media']
        date = row[1]['publication_date']
        url = row[1]['url']
        article = row[1]['article']

        candidates_df = articles_df[articles_df['media'] != media]
        candidates_df = candidates_df[candidates_df['publication_date'] > date]
    
        candidates_df = candidates_df[candidates_df['publication_date'] < (date + timedelta(days=timeframe))]
        
        tpairs_df = pd.DataFrame({'tweet_id_A':tweet_id, 'media_A':media, 'article_A':(title+' '+headline), 
                                 'url_A':url, 'tweet_id_B':candidates_df['tweet_id'], 
                                 'media_B':candidates_df['media'], 
                                 'article_B':(candidates_df['title']+' '+candidates_df['headline']), 
                                 'url_B':candidates_df['url'], 't':abs((date - candidates_df['publication_date']).dt.days)})
        
        pairs_df = pd.concat([pairs_df, tpairs_df])

# %%
pairs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83536 entries, 773 to 14926
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_id_A  83536 non-null  object
#  1   media_A     83536 non-null  object
#  2   article_A   83536 non-null  object
#  3   url_A       83536 non-null  object
#  4   tweet_id_B  83536 non-null  object
#  5   media_B     83536 non-null  object
#  6   article_B   83536 non-null  object
#  7   url_B       83536 non-null  object
#  8   t           83536 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 6.4+ MB

# %%
# COMPUTE COSINE SIMILARITY OF TF-IDF FOR EACH PAIR OF ARTICLES
cosine_matrix = cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets) 
pairs_df = add_similarity_column(pairs_df, mapping_keys, cosine_matrix, 'tf-idf')
# Out:
# ---GETTING NEWS
# ---STEM
# ---COMPUTE TF-IDF
# ---COMPUTE COSINE SIMILARITY MATRIX

# %%
T = [10, 15, 30, 60]
epsilon_pairs_df = pd.DataFrame()

epsilon = 0.35
for row in k1_articles.iterrows():
    tweet_pairs = pairs_df[pairs_df['tweet_id_A']==row[1]['tweet_id']]
    for timeframe in T:
        tweet_pairs_t = tweet_pairs[tweet_pairs['tf-idf']<=epsilon]
        #tweet_pairs_t = tweet_pairs_t[tweet_pairs_t['tf-idf']<=epsilon]
        try:
            epsilon_pairs_df = pd.concat([epsilon_pairs_df,tweet_pairs_t.sample(n=2)])
        except:
            try:
                epsilon_pairs_df = pd.concat([epsilon_pairs_df,tweet_pairs_t.sample(n=1)])
            except:
                pass

# %%
epsilon_pairs_df['t'] = abs(epsilon_pairs_df['t'])

# %%
epsilon_pairs_df.head()
# Out:
#                 tweet_id_A     media_A  \
# 8348   1313566194964799490  voz_populi
# 8348   1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 4118   1313566194964799490  voz_populi
#
#                                                article_A  \
# 8348   septimo implicado violacion grupal menor fuent...
# 8348   septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 4118   septimo implicado violacion grupal menor fuent...
#
#                                                    url_A           tweet_id_B  \
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 4118   https://www.vozpopuli.com/actualidad/detenido-...  1313846788865044480
#
#           media_B                                          article_B  \
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 4118   larazon_es  nueve detenidos violacion menor namename trata...
#
#                                                    url_B  t    tf-idf
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 4118   https://www.larazon.es/comunidad-valenciana/20...  1  0.296127

# %%
epsilon_pairs_df.to_csv('data/pairs_epsilon.csv')

# %% [markdown]
# # 3. Compute similarity

# %%
articles_df = articles_df.sort_values(by='publication_date')

# %%
t = 30
pairs_df = pd.DataFrame()
id_A = []
id_B = []
T = []
count = 0

for row in articles_df.iterrows():
    tweet_id_A = row[1]['tweet_id']
    date = row[1]['publication_date']
    date_df = articles_df[articles_df["publication_date"] >= (date)] 
    date_df = date_df[date_df["publication_date"] < (date + timedelta(days=t))] 
    for row_date in date_df.iterrows():
        tweet_id_B = row_date[1]['tweet_id']
        id_A.append(tweet_id_A)
        id_B.append(tweet_id_B)
        T.append(abs((date - row_date[1]['publication_date']).days))
        
    if count in [1000, 5000, 10000, 14000]:
        print(count)
        
    count += 1
# Out:
# 1000
# 5000
# 10000
# 14000

# %%
pairs_df = pd.DataFrame({'tweet_id_A':id_A, 'tweet_id_B':id_B, 'days':T})

# %%
# COMPUTE COSINE SIMILARITY OF TF-IDF FOR EACH PAIR OF ARTICLES
cosine_matrix = cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets) 
pairs_df = add_similarity_column(pairs_df, mapping_keys, cosine_matrix, 'tf-idf')
# Out:
# ---GETTING NEWS
# ---STEM
# ---COMPUTE TF-IDF
# ---COMPUTE COSINE SIMILARITY MATRIX

# %%
pairs_df.head()

# %%
pairs_df.info()

# %%
cases_df = pairs_df[pairs_df['tf-idf']<0.35]

# %%
cases_df.info()

# %%
#Construct graph
sources = list(cases_df['tweet_id_A'].values)
targets = list(cases_df['tweet_id_B'].values)
G = nx.Graph()
G.add_nodes_from(sources)
G.add_nodes_from(targets)
for i in range(len(sources)):
    G.add_edge(sources[i], targets[i])

# %%
#Numerate connected components
cc_list = list(nx.connected_components(G))
cont = 0
cc_elements = []
cc_id = []
for cc in cc_list:
    for elem in cc:
        cc_elements.append(elem)
        cc_id.append(cont)
    cont += 1

# %%
#Save connected components
connected_components_df = pd.DataFrame({'cluster_id':cc_id, 'tweet_id':cc_elements})

# %%
connected_components_df.info()

# %%
connected_components_df.head()

# %%
connected_components_df.to_csv('data/cases_df.csv', index=False)

# %%
len(list(nx.connected_components(G)))
