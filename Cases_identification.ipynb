# %%
import warnings
warnings.filterwarnings('ignore')
from pyemd import emd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score,  precision_recall_curve
from gensim.models.keyedvectors import KeyedVectors
from nltk.stem.snowball import SpanishStemmer
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from datetime import datetime, timedelta
import lxml.etree as ET
import seaborn as sns
import pandas as pd
import numpy as np
import regex as re
import itertools
import unidecode
import spacy
import html
import os
import networkx as nx

# %%
NEWS_PATH = 'data/news/'
FASTTEXT_W2V_PATH = 'utilities/embeddings-l-model.vec'

# %%
def listdir_checked(path, unwanted = ['.DS_Store']):
    '''
    Discard unwanted files or directories when listing the elements in a given path
    '''
    return (f for f in os.listdir(path) if f not in unwanted)


def normalize_string(to_normalize, encoded = False):
    '''
    Normalize text given a string
    '''
    text = str(to_normalize).lower()  # lowering text
    if encoded: 
        text = ' '.join([html.unescape(term) for term in text.split()])
    text = unidecode.unidecode(text)

    text = re.sub(r'[^\w\s]', '', text)  # removing all the punctuations
    last_text = text.split()  # tokenize the text

    # remove stopwords
    stopwords_set = set(stopwords.words("spanish"))
    stopwords_set = stopwords_set.union(set(["name"]))
    
    last_text = ' '.join([x for x in last_text if (x not in stopwords_set)])
    return last_text


def classify_entities(doc):
    '''
    Given an nlp doc, returns:
    * A dictonary with the entities grouped by type: 'PER', 'LOC', 'ORG' and 'MISC'
    * A list with all the entities
    '''
    classif_dict = {}
    classif_list = []
    for ent in doc.ents:
        try:
            classif_list.append(ent)
            classif_dict[ent.label_].append(ent)
        except:
            classif_dict[ent.label_] = [ent]
    # Check that the dict has all the keys
    for key in ['PER', 'LOC', 'ORG', 'MISC']:
        if key not in classif_dict.keys():
            classif_dict[key] = None

    return classif_dict, classif_list


def create_articles_dictionary(NEWS_PATH):
    '''
    Import articles information.
    Articles are stored in directories in the NEWS_PATH.
    '''
    data = {}               # keys: media, value: list of dictionaries with info about the news articles of the given media
    unique_urls = []        # list to store unique urls to discard repeated ones
    repeated_data = {}      # store repeated articles following the same format as 'data' dictionary


    for year in listdir_checked(NEWS_PATH):
            for month in listdir_checked(NEWS_PATH + '/' + year):
                    for file in listdir_checked(NEWS_PATH + '/' + year + '/' + month):
                        try:
                            full_path = NEWS_PATH + '/' + year + '/' + month + '/' + file
                            # Read xml file - info stored following NewsML-G2 format
                            root = ET.parse(full_path).getroot()
                            # Parse news
                            media = file.rsplit('_', 1)[0]
                            # Check repeated urls
                            url = root.findall(".//infoSource")[0].get("uri")
                            str_date = root.findall('.//contentMeta')[0].find('contentCreated').text[:10]
                            info = {
                                'id': file.split(':')[-1].replace('.xml', ''),
                                'media': media,
                                'publication_date': datetime.strptime(str_date, '%Y-%m-%d'),
                                'title': normalize_string(root.findall('.//itemRef')[0].find('title').text, encoded = True),
                                'headline': normalize_string(root.findall(".//itemRef")[0].find('description').text.strip(), encoded = True),
                                'article': normalize_string(root.findall('.//itemRef')[1].find('description').text.strip(), encoded = True),                'url': url
                            }

                            if url not in unique_urls:
                                unique_urls.append(url)
                                try:
                                    data[media].append(info)
                                except:
                                    data[media] = [info]

                            else:
                                try:
                                    repeated_data[media].append(info)
                                except:
                                    repeated_data[media] = [info]
                        except:
                            print(file)

    return data, repeated_data


def load_elements(data):
    # EXTRACT ENTITIES
    '''
    Entities will be stored two arrays:
    * entities - all entities
    * summary_entities - entities from the title and head (summary)
    Auxiliary variables:
    * mapping_keys - dict with key: tweet id -> value: absolute position in entities and summary_entities
    '''
    mapping_keys = {}  # key: tweet id -> value: absolute position in all_entities
    mapping_tweets = {}  # key: value -> tweet_id: absolute position in all_entities
    counter = 0

    summary_entities = []
    article_entities = []

    nlp = spacy.load("es_core_news_sm")

    for media, new in data.items():
        print('------ MEDIA:', media)
        for element in new:
            mapping_keys[element['id']] = counter
            mapping_tweets[counter] = element['id']
            # Get entities from each part of the new
            try:
                title_doc = nlp(element['title'])
                headline_doc = nlp(element['headline'])
                article_doc = nlp(element['article'])
            except:
                print(f"Problem extracting entities from article identified with tweet_id = {element['id']}")
                pass

            # Classify entities
            title_dict, title_list = classify_entities(title_doc)
            headline_dict, headline_list = classify_entities(headline_doc)
            article_dict, article_list = classify_entities(article_doc)

            # Add entities into data
            element['title_entities'] = title_dict
            element['headline_entities'] = headline_dict
            element['article_entities'] = article_dict

            # Store into entities and summary_entities array
            summary_entities.append(title_list + headline_list)
            article_entities.append(article_list)

            counter += 1
            
    return summary_entities, article_entities, mapping_keys, mapping_tweets


def wmdistance(data, mapping_keys, pairs_df, mapping_tweets):
    N = len(mapping_keys)
    articles = [None] * N
    
    for media, new in data.items():
        for element in new:
            try:
                pos = mapping_keys[element['id']]
                articles[pos] = normalize_string(element['title'])+' '+normalize_string(element['headline'].split('.')[0])
            except:
                pass
    
    wordvectors_fasttext_file = FASTTEXT_W2V_PATH
    wordvectors = KeyedVectors.load_word2vec_format(wordvectors_fasttext_file)
    wmd_matrix = np.zeros(shape=(N,N))
    
    for row in pairs_df.iterrows():
        
        id_A = row[1]['tweet_id_A']
        id_B = row[1]['tweet_id_B']
        
        i = mapping_keys[str(id_A)]
        j = mapping_keys[str(id_B)]

        distance = wordvectors.wmdistance(articles[i], articles[j])
        wmd_matrix[i,j] = distance
        wmd_matrix[j,i] = distance
    
    return wmd_matrix


def cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets):
    # GET NEWS ARTICLES
    print('---GETTING NEWS')
    N = len(mapping_keys)
    articles = [None] * N
    for media, new in data.items():
        for element in new:
            try:
                pos = mapping_keys[element['id']]
                
                articles[pos] = normalize_string(element['title'] + ' ' + 
                                                 element['headline'] + ' ' + 
                                                 element['article'])
            except:
                pass

    # COMPUTE TF-IDF
    # Stem
    print('---STEM')
    stemmer = SpanishStemmer(ignore_stopwords=False)
    for i, article in enumerate(articles):
        try:
            articles[i] = str([stemmer.stem(word) for word in article.split()])
        except:
            articles[i] = 'null'
            pass
        
    # Compute tf-idf
    print('---COMPUTE TF-IDF')  
    stopwords_spanish = [word.encode().decode('utf-8') for word in stopwords.words('spanish')] # Remove stopwords
    vectorizer = TfidfVectorizer(stop_words=stopwords_spanish)
    X = vectorizer.fit_transform(articles)

    # COMPUTE COSINE SIMILARITY MATRIX
    print('---COMPUTE COSINE SIMILARITY MATRIX')
    cosine_sim_matrix = np.zeros(shape=(N, N))
    for row in pairs_df.iterrows():
        
        id_A = row[1]['tweet_id_A']
        id_B = row[1]['tweet_id_B']
        
        try:
            i = mapping_keys[str(id_A)]
            j = mapping_keys[str(id_B)]
            
            similarity = cosine_similarity(X[i], X[j])[0][0]
            cosine_sim_matrix[i, j] = 1-similarity
            cosine_sim_matrix[j, i] = 1-similarity
        
        except:
            print('ERROR WITH: ', id_A, id_B)
            
    return cosine_sim_matrix


def add_similarity_column(pairs_df, mapping_keys, similarity_matrix, column_name):
    '''
    Arguments:
     * pairs_df
         - pd.DataFrame
         - contains pairs of tweet_ids --> column names: [tweet_id_A, tweet_id_B]
     * mapping_keys
         - dictionary
         - key: tweet_id, value: position
     * similarity_matrix
         - np.matrix
         - symmetrical matrix with the similarity between tweets
     * column_name
         - string
         - name of the new column to be added in pairs_df
    '''
    similarity_pairs = []               # Create list with the same order as pairs_df
    for i, row in pairs_df.iterrows():
        tid_A = row['tweet_id_A']       # Obtain tweet id
        tid_B = row['tweet_id_B']       # Get the position of each article in the matrix
        pos_A = mapping_keys[tid_A]
        pos_B = mapping_keys[tid_B]
        similarity_pairs.append(similarity_matrix[pos_A, pos_B])             # Order similarity following pairs_df order
    pairs_df.insert(len(pairs_df.columns), column_name, similarity_pairs)   # Add new column
    return pairs_df

def componentes_conexas(G):
    def visita(v): #subrutina
        cc[v] = componente_actual 
        for u in G[v]:
            if u not in cc: #u no visitado <=> u no tiene componente
                visita(u)
    cc = dict() #Etiqueta de componente conexa
    componente_actual = 0
    for v in G:
        if v not in cc:
            visita(v)
            componente_actual += 1
    return cc

# %% [markdown]
# # 1. Load Data

# %%
data, repeated_data = create_articles_dictionary(NEWS_PATH)
# Out:
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1466063287485878280.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1475242375102480387.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1470254067817627656.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1471080345189638144.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1471395805697302530.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1468135693566238723.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1466586222609022988.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1476569001337761798.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1469945355534049284.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1469394348651466752.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1466147794167730184.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1472879722539454466.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1470381993296683015.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1473415316722143241.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1471808895521734661.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1472680641309417474.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1467914443489218565.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1468430508518514688.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1470166895391383557.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1471205753826516992.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1466368513191329792.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1470370668998848514.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1475067541026488323.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1470484019531988995.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1472487845466189824.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1467910817546919947.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1468214331674439681.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1473564837661839360.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1476465008842260482.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1466388936457003009.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1469384796929511435.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1476833430117752833.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1469748778186031108.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1467092933040029701.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1475383668134887428.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1472611128694001677.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1473703630310187010.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1462129154753798151.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459101210183614465.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1460873672672137223.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1460140591745060867.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456626354032631814.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463908833122791434.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459986423650607110.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1465123575552172032.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459790629525934080.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463193969781792771.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1462360423051796481.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459980298414927872.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456049185082552320.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463062017749786624.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1457302849977737218.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1464191200605487108.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1458796906688258056.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1455759723496710150.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1455793868390154242.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1462199038657417224.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456692069712416771.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1457783307005927434.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1458558837552734209.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1460047690520223746.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459155519315185672.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1455847492424278024.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1460185304753528835.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456318024324206601.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1457460600875925505.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456551074689585159.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463130461534928897.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459185337826218006.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463697038751711236.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1462888255570038787.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1455131427331248132.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1461523454348476423.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1464881826862878721.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1457839242151972865.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1456036623079063555.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1459195166087163905.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463138011147874306.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1461260689658585092.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1463836362541604873.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1502587201594400769.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1496811500434042886.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1482631431474106374.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1485228059682914305.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1486466479755182082.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1484585819495145473.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1481735999227052037.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1478143294639063043.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1483862001004781572.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1487761870102614022.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1483460169237512203.xml
# el_pais_urn:newsml:Ediciones EL PAÍS S.L.:20220606:1477965714426318856.xml

# %%
articles_df = pd.DataFrame()

for media in data.keys():
    for new in data[media]:
        tweet_id = new['id']
        title = normalize_string(new['title'])
        headline = normalize_string(new['headline'])
        url = new['url']
        publication_date = new['publication_date']
        article = normalize_string(new['article'])
        
        articles_df = articles_df.append({'tweet_id': tweet_id, 'media': media, 'title': title, 
                                          'headline': headline, 'url': url, 'publication_date': publication_date,
                                          'article': article},
                                       ignore_index=True)

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14961 entries, 0 to 14960
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          14961 non-null  object
#  1   media             14961 non-null  object
#  2   title             14961 non-null  object
#  3   headline          14961 non-null  object
#  4   url               14961 non-null  object
#  5   publication_date  14961 non-null  datetime64[ns]
#  6   article           14961 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 818.3+ KB

# %%
summary_entities, article_entities, mapping_keys, mapping_tweets = load_elements(data)
# Out:
# ------ MEDIA: 20m
# ------ MEDIA: okdiario
# ------ MEDIA: LaVanguardia
# ------ MEDIA: europapress
# ------ MEDIA: larazon_es
# ------ MEDIA: abc_es
# ------ MEDIA: elperiodico
# ------ MEDIA: elmundoes
# ------ MEDIA: publico_es
# ------ MEDIA: rtve
# ------ MEDIA: el_pais
# ------ MEDIA: La_SER
# ------ MEDIA: informativost5
# ------ MEDIA: ElHuffPost
# ------ MEDIA: voz_populi
# ------ MEDIA: COPE
# ------ MEDIA: elconfidencial
# ------ MEDIA: elespanolcom
# ------ MEDIA: eldiarioes
# ------ MEDIA: laSextaTV
# ------ MEDIA: OndaCero_es
# ------ MEDIA: noticias_cuatro
# ------ MEDIA: libertaddigital
# ------ MEDIA: EFEnoticias_ES

# %% [markdown]
# # 2. Determine parameters epsilon and T

# %%
#Select 40 random articles
k1_articles = articles_df.sample(n=40)
k1_articles
# Out:
#                   tweet_id            media  \
# 11968  1313566194964799490       voz_populi
# 9084   1217143087912443906          el_pais
# 993    1367886408946487297              20m
# 8899   1501915717909635072             rtve
# 10650  1288776599458869248   informativost5
# 4639   1493533049199415296       larazon_es
# 13742  1431149484264890370       eldiarioes
# 224    1235086320059334658              20m
# 14073  1287630047675908097        laSextaTV
# 11583  1442701583247101961       ElHuffPost
# 14885  1377160355214807047  libertaddigital
# 749    1475931304050970632              20m
# 11078  1420496535318523904   informativost5
# 12435  1425139561924022287             COPE
# 1904   1273958500490715136         okdiario
# 8355   1314618125799751682       publico_es
# 3564   1490494276815536130      europapress
# 11925  1230052548024901634       voz_populi
# 12160  1231174796731351041             COPE
# 13923  1342907812830208008        laSextaTV
# 14082  1282073429978615808        laSextaTV
# 249    1235609816854192129              20m
# 3985   1296865869998546945       larazon_es
# 4004   1253024521017331712       larazon_es
# 5699   1386634236917133314           abc_es
# 2162   1382667218832478208         okdiario
# 3668   1301373104439152640       larazon_es
# 555    1276122365194375168              20m
# 11413  1518343943737516032   informativost5
# 11003  1367212936251518983   informativost5
# 1282   1381104472118677507              20m
# 396    1278611296842285056              20m
# 490    1293210254637924353              20m
# 5214   1255945015819472900           abc_es
# 3317   1367150702032748551      europapress
# 10646  1288867196647682048   informativost5
# 3783   1265504254267138049       larazon_es
# 652    1433323812645392386              20m
# 7809   1355558620512006144        elmundoes
# 4242   1456570743760818182       larazon_es
#
#                                                    title  \
# 11968           septimo implicado violacion grupal menor
# 9084   recurre archivo causa culpar falsamente magreb...
# 993    anos carcel militar pederasta abusar grabar ex...
# 8899   justicia francesa mantiene acusacion violacion...
# 10650                 mujer forzada prostituirse 11 anos
# 4639           denuncia acoso sufrio redes sociales tras
# 13742  alumnas colegio concertado denuncian redes soc...
# 224     cada 20 jovenes 15 19 anos sido violada denuncia
# 14073  menor acusado causar cortes brazo intentar apu...
# 11583  cantante r declarado culpable trafico sexual c...
# 14885  balear rechaza creacion comision investigacion...
# 749    profesor violin enfrenta cinco anos prision ab...
# 11078                                   presenta violeta
# 12435    gobernador dimite tras acusaciones acoso sexual
# 1904
# 8355            juicio joven presuntamente abuso hermana
# 3564   dice victimas abusos pueden seguir silenciadas...
# 11925  izquierda balear rechaza crear comision abusos...
# 12160       dos menores difundir fotografia intima menor
# 13923  nina 12 anos acuchilla presunto maltratador madre
# 14082          exhibicionismo delante cuatro ninas playa
# 249    once anos carcel abusar hijastra 12 anos casa ...
# 3985                 violacion menor mas treinta hombres
# 4004   pasa menores 14 17 anos podran salir partir 26...
# 5699   hombre acusado agredir sexualmente dos ninas 1...
# 2162   mujer distribuir imagenes sexuales hija menor ...
# 3668              orgia millon dolares botella refrescos
# 555    tsjn confirma condena 3 anos 3 meses prision d...
# 11413  17 anos prision abusar tres sobrinas pesar ret...
# 11003       8 anos carcel hombre abuso hijo 2 anos grabo
# 1282   hombre abuso seis anos sobrinas menores pareja...
# 396               denuncia inquilina okupa pide justicia
# 490    tiktoker enfrenta hombre acosando sexualmente ...
# 5214   tambien abusos sexuales mujeres industria musical
# 3317     prision fianza detenido agredir exnovia 16 anos
# 10646                            alphabet defienden eeuu
# 3783                              cabana horrores bestia
# 652    siete afroamericanos ee uu 70 anos despues ser...
# 7809                protestas violacion joven venezolana
# 4242   electricista confiesa dos asesinatos vejacione...
#
#                                                 headline  \
# 11968  fuentes instituto armado hombre sido detenido ...
# 9084   juez sobreseyo delito odio agresion mujer play...
# 993    militar detenido marco sido condenado siete an...
# 8899   sala instruccion considera existen indicios gr...
# 10650  saldar deuda grupo criminal trajo personas sid...
# 4639   actor director mostro mensajes odio homofobo s...
# 13742  centro anuncia investigacion interna tras narr...
# 224    millones cada veinte jovenes 15 19 anos vive m...
# 14073  agredido presentaba rostro ensangrentado vario...
# 11583  personas testificado artista conocido exitos i...
# 14885  escandalo prostitucion menores tuteladas centr...
# 749    juzgado numero 3 celebro pasado lunes juicio p...
# 11078  mujeres victimas violencia machista sexual emp...
# 12435  gobernador disculpado si alguna mujer ofendida...
# 1904   tsja confirmado absolucion padre enfrento 15 a...
# 8355   victima proceso hermana menor joven 18 anos de...
# 3564                                       not specified
# 11925  dos propuestas misma finalidad debatido votado...
# 12160  investigacion comenzo inicios presente mes mad...
# 13923  menor habia grabado audio discusion demostrar ...
# 14082  padre menores dos 11 anos percato hombre ensen...
# 249    tsjm ratificado sentencia madrilena condeno on...
# 3985   primer ministro calificado incidente crimen hu...
# 4004   rectifico martes medida anunciada limitaba sal...
# 5699   tercera adolescente amiga victimas dio aviso l...
# 2162                                                 not
# 3668   actor protagonizo primer gran escandalo sexual...
# 555      tsjn confirmado sentencia dictada noviembre pas
# 11413  confirmado condena 17 anos cuatro meses prisio...
# 11003  padre vecino grabo fotografio hijo poses carac...
# 1282   condenado 27 anos carcel hombre 56 anos abusar...
# 396    actriz presentadora exconcursante varios reali...
# 490    video chica joven hecho viral tiktok mostrar e...
# 5214   cantante vuelta nueva cancion habla depresion ...
# 3317                                       not specified
# 10646  defendido subcomision examina poder mercado po...
# 3783   centro operaciones tras salir carcel violar ma...
# 652    grupo afroamericanos conocidos condenados jura...
# 7809   victima relato comenzo sentirse mareada tras b...
# 4242   filmo fotografio si mismo doce anos abusando s...
#
#                                                      url publication_date  \
# 11968  https://www.vozpopuli.com/actualidad/detenido-...       2020-10-06
# 9084   https://elpais.com/ccaa/2020/01/14/valencia/15...       2020-01-14
# 993    https://www.20minutos.es/noticia/4609407/0/sie...       2021-03-05
# 8899   https://www.rtve.es/noticias/20220310/justicia...       2022-03-10
# 10650  https://www.telecinco.es/informativos/sociedad...       2020-07-30
# 4639   https://www.larazon.es/gente/famosos/20220214/...       2022-02-14
# 13742  https://www.eldiario.es/galicia/antiguas-alumn...       2021-08-26
# 224    https://www.20minutos.es/noticia/4174351/0/una...       2020-03-04
# 14073  https://www.lasexta.com/noticias/sociedad/dete...       2020-07-26
# 11583  https://www.huffingtonpost.es/entry/el-cantant...       2021-09-28
# 14885  https://www.libertaddigital.com/espana/2021-03...       2021-03-31
# 749    https://www.20minutos.es/noticia/4933967/0/un-...       2021-12-28
# 11078  https://www.telecinco.es/informativos/nacional...       2021-07-28
# 12435  https://www.cope.es/actualidad/internacional/n...       2021-08-10
# 1904   https://okdiario.com/andalucia/tsja-confirma-a...       2020-06-19
# 8355   https://www.publico.es/sociedad/violencia-sexu...       2020-10-09
# 3564   https://www.europapress.es/sociedad/noticia-sa...       2022-02-06
# 11925  https://www.vozpopuli.com/espana/politica/parl...       2020-02-19
# 12160  https://www.cope.es/actualidad/espana/noticias...       2020-02-22
# 13923  https://www.lasexta.com/noticias/sociedad/nina...       2020-12-26
# 14082  https://www.lasexta.com/noticias/sociedad/dete...       2020-07-11
# 249    https://www.20minutos.es/noticia/4176723/0/con...       2020-03-05
# 3985   https://www.larazon.es/actualidad/20200821/3xn...       2020-08-21
# 4004   https://www.larazon.es/sociedad/20200422/6dtao...       2020-04-22
# 5699   https://www.abc.es/espana/galicia/abci-detenid...       2021-04-26
# 2162   https://okdiario.com/andalucia/detenida-mujer-...       2021-04-15
# 3668   https://www.larazon.es/cataluna/20200902/ea7ky...       2020-09-02
# 555    https://www.20minutos.es/noticia/4303635/0/tsj...       2020-06-25
# 11413  https://www.telecinco.es/informativos/sociedad...       2022-04-24
# 11003  https://www.telecinco.es/informativos/sociedad...       2021-03-03
# 1282   https://www.20minutos.es/noticia/4651685/0/hom...       2021-04-10
# 396    https://www.20minutos.es/noticia/4311119/0/mon...       2020-07-02
# 490    https://www.20minutos.es/gonzoo/noticia/435000...       2020-08-11
# 5214   https://www.abc.es/cultura/musica/abci-alanis-...       2020-04-30
# 3317   https://www.europapress.es/andalucia/malaga-00...       2021-03-03
# 10646  https://www.telecinco.es/informativos/internac...       2020-07-30
# 3783   https://www.larazon.es/sociedad/20200526/yypzv...       2020-05-26
# 652    https://www.20minutos.es/noticia/4807658/0/ind...       2021-09-02
# 7809   https://www.elmundo.es/internacional/2021/01/2...       2021-01-29
# 4242   https://www.larazon.es/internacional/20211105/...       2021-11-04
#
#                                                  article
# 11968  detenido hombre 32 anos presunta implicacion v...
# 9084   seccion delitos recurrido archivo investigacio...
# 993    militar detenido marco sido condenado siete an...
# 8899   confirmo jueves acusacion violacion agresion s...
# 10650  liberado municipio mujer forzada prostituirse ...
# 4639   encargados abrir ansiada alfombra roja pasado ...
# 13742  vez ser premiado vigues distinguido deberia se...
# 224    millones cada veinte jovenes 15 19 anos vive m...
# 14073  local detenido menor edad presunto autor asest...
# 11583  cantante estadounidense r sido declarado lunes...
# 14885  escandalo prostitucion menores tuteladas centr...
# 749    juzgado numero 3 celebro pasado lunes juicio p...
# 11078  ministra presentado hoy llamado violeta inicia...
# 12435  gobernador anunciado dimitira plazo 14 dias ev...
# 1904   tsja confirmado absolucion padre enfrento 15 a...
# 8355   acordado apertura juicio oral joven presuntame...
# 3564   madrid 6 europa press presidente aseverado dom...
# 11925  rechazado martes propuestas crear comision inv...
# 12160  etpj esclarecido mes delito revelacion secreto...
# 13923  nina 12 anos defendido madre abusos padrastro ...
# 14082  local detenido hombre 41 anos presunto delito ...
# 249    tsjm ratificado sentencia madrilena condeno on...
# 3985   israelies salido jueves noche treintena ciudad...
# 4004   ministro anuncio ultima hora tarde martes fina...
# 5699   vecino sido detenido ultima hora tarde domingo...
# 2162   detenido mujer distribuir traves aplicaciones ...
# 3668   hablar cine comico mudo rapidamente vienen mem...
# 555    tsjn confirmado sentencia dictada noviembre pa...
# 11413  confirmado condena 17 anos cuatro meses prisio...
# 11003  pedido ocho anos carcel hombre vecino haber ab...
# 1282   condenado 27 anos carcel hombre 56 anos abusar...
# 396    actriz presentadora exconcursante varios reali...
# 490    video chica joven hecho viral tiktok mostrar e...
# 5214   tormenta sacudido cimientos industria cine tra...
# 3317   malaga 3 europa press numero 1 decretado ingre...
# 10646  consejeros delegados cuatro mayores tecnologic...
# 3783   peligroso delincuente sexual nunca reinsertan ...
# 652    grupo afroamericanos conocidos condenados jura...
# 7809   organizaciones mostraron indignacion traves va...
# 4242   trabajador hospital britanico admitio haber as...

# %%
wordvectors_fasttext_file = FASTTEXT_W2V_PATH
wordvectors = KeyedVectors.load_word2vec_format(wordvectors_fasttext_file)

# %%
#Construct pairs of the articles
T = [10, 15, 30, 60]
cases_df = pd.DataFrame(columns=['tweet_id_A', 'article_A', 'url_A', 'tweet_id_B', 'article_B', 'url_B', 'vmdistance'])
epsilon = 0.50

pairs_df = pd.DataFrame()

for row in k1_articles.iterrows():
    for timeframe in T:
        tweet_id = row[1]['tweet_id']
        title = row[1]['title']
        headline = row[1]['headline']
        media = row[1]['media']
        date = row[1]['publication_date']
        url = row[1]['url']
        article = row[1]['article']

        candidates_df = articles_df[articles_df['media'] != media]
        candidates_df = candidates_df[candidates_df['publication_date'] > date]
    
        candidates_df = candidates_df[candidates_df['publication_date'] < (date + timedelta(days=timeframe))]
        
        tpairs_df = pd.DataFrame({'tweet_id_A':tweet_id, 'media_A':media, 'article_A':(title+' '+headline), 
                                 'url_A':url, 'tweet_id_B':candidates_df['tweet_id'], 
                                 'media_B':candidates_df['media'], 
                                 'article_B':(candidates_df['title']+' '+candidates_df['headline']), 
                                 'url_B':candidates_df['url'], 't':abs((date - candidates_df['publication_date']).dt.days)})
        
        pairs_df = pd.concat([pairs_df, tpairs_df])

# %%
pairs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67564 entries, 581 to 14878
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_id_A  67564 non-null  object
#  1   media_A     67564 non-null  object
#  2   article_A   67564 non-null  object
#  3   url_A       67564 non-null  object
#  4   tweet_id_B  67564 non-null  object
#  5   media_B     67564 non-null  object
#  6   article_B   67564 non-null  object
#  7   url_B       67564 non-null  object
#  8   t           67564 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 5.2+ MB

# %%
# COMPUTE COSINE SIMILARITY OF TF-IDF FOR EACH PAIR OF ARTICLES
cosine_matrix = cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets) 
pairs_df = add_similarity_column(pairs_df, mapping_keys, cosine_matrix, 'tf-idf')
# Out:
# ---GETTING NEWS
# ---STEM
# ---COMPUTE TF-IDF
# ---COMPUTE COSINE SIMILARITY MATRIX

# %%
pairs_df.to_csv('data/pairs.csv', index=False)

# %%
pairs_df.head()
# Out:
#               tweet_id_A     media_A  \
# 581  1313566194964799490  voz_populi
# 584  1313566194964799490  voz_populi
# 594  1313566194964799490  voz_populi
# 599  1313566194964799490  voz_populi
# 603  1313566194964799490  voz_populi
#
#                                              article_A  \
# 581  septimo implicado violacion grupal menor fuent...
# 584  septimo implicado violacion grupal menor fuent...
# 594  septimo implicado violacion grupal menor fuent...
# 599  septimo implicado violacion grupal menor fuent...
# 603  septimo implicado violacion grupal menor fuent...
#
#                                                  url_A           tweet_id_B  \
# 581  https://www.vozpopuli.com/actualidad/detenido-...  1314285692734836739
# 584  https://www.vozpopuli.com/actualidad/detenido-...  1314459911636627456
# 594  https://www.vozpopuli.com/actualidad/detenido-...  1316141161946517509
# 599  https://www.vozpopuli.com/actualidad/detenido-...  1316323661813604352
# 603  https://www.vozpopuli.com/actualidad/detenido-...  1314473937544372225
#
#     media_B                                          article_B  \
# 581     20m  santero abusar sexualmente menor santero 61 an...
# 584     20m  acusado nueva violacion exproductor cine acusa...
# 594     20m  campana busca extorsionar falsos videos conten...
# 599     20m  dos jovenes agredir sexualmente companera trab...
# 603     20m  definitivamente denuncia abusos padre vinculad...
#
#                                                  url_B  t    tf-idf
# 581  https://www.20minutos.es/noticia/4411174/0/det...  2  0.889681
# 584  https://www.20minutos.es/noticia/4411260/0/har...  3  0.936409
# 594  https://www.20minutos.es/noticia/4415697/0/ale...  7  0.989851
# 599  https://www.20minutos.es/noticia/4416191/0/det...  8  0.922552
# 603  https://www.20minutos.es/noticia/4411362/0/arc...  3  0.925586

# %%
T = [10, 15, 30, 60]
epsilon_pairs_df = pd.DataFrame()

epsilon = 0.35
for row in k1_articles.iterrows():
    tweet_pairs = pairs_df[pairs_df['tweet_id_A']==row[1]['tweet_id']]
    for timeframe in T:
        tweet_pairs_t = tweet_pairs[tweet_pairs['tf-idf']<=epsilon]
        #tweet_pairs_t = tweet_pairs_t[tweet_pairs_t['tf-idf']<=epsilon]
        try:
            epsilon_pairs_df = pd.concat([epsilon_pairs_df,tweet_pairs_t.sample(n=2)])
        except:
            try:
                epsilon_pairs_df = pd.concat([epsilon_pairs_df,tweet_pairs_t.sample(n=1)])
            except:
                pass

# %%
epsilon_pairs_df.head()
# Out:
#                 tweet_id_A     media_A  \
# 8348   1313566194964799490  voz_populi
# 8348   1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 4118   1313566194964799490  voz_populi
#
#                                                article_A  \
# 8348   septimo implicado violacion grupal menor fuent...
# 8348   septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 4118   septimo implicado violacion grupal menor fuent...
#
#                                                    url_A           tweet_id_B  \
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 4118   https://www.vozpopuli.com/actualidad/detenido-...  1313846788865044480
#
#           media_B                                          article_B  \
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 4118   larazon_es  nueve detenidos violacion menor namename trata...
#
#                                                    url_B  t    tf-idf
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 4118   https://www.larazon.es/comunidad-valenciana/20...  1  0.296127

# %%
epsilon_pairs_df['t'] = abs(epsilon_pairs_df['t'])

# %%
epsilon_pairs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 8348 to 11149
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_id_A  24 non-null     object
#  1   media_A     24 non-null     object
#  2   article_A   24 non-null     object
#  3   url_A       24 non-null     object
#  4   tweet_id_B  24 non-null     object
#  5   media_B     24 non-null     object
#  6   article_B   24 non-null     object
#  7   url_B       24 non-null     object
#  8   t           24 non-null     int64
#  9   tf-idf      24 non-null     float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.1+ KB

# %%
epsilon_pairs_df.head()
# Out:
#                 tweet_id_A     media_A  \
# 8348   1313566194964799490  voz_populi
# 8348   1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 14142  1313566194964799490  voz_populi
# 4118   1313566194964799490  voz_populi
#
#                                                article_A  \
# 8348   septimo implicado violacion grupal menor fuent...
# 8348   septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 14142  septimo implicado violacion grupal menor fuent...
# 4118   septimo implicado violacion grupal menor fuent...
#
#                                                    url_A           tweet_id_B  \
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 8348   https://www.vozpopuli.com/actualidad/detenido-...  1313852460839165952
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 14142  https://www.vozpopuli.com/actualidad/detenido-...  1313850324902346754
# 4118   https://www.vozpopuli.com/actualidad/detenido-...  1313846788865044480
#
#           media_B                                          article_B  \
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 8348   publico_es  nueve detenidos cuatro prision violacion menor...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 14142   laSextaTV  noveno hombre violacion grupo nina lname arres...
# 4118   larazon_es  nueve detenidos violacion menor namename trata...
#
#                                                    url_B  t    tf-idf
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 8348   https://www.publico.es/sociedad/pais-valencia-...  1  0.276703
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 14142  https://www.lasexta.com/noticias/sociedad/dete...  1  0.291730
# 4118   https://www.larazon.es/comunidad-valenciana/20...  1  0.296127

# %%
epsilon_pairs_df.to_csv('data/pairs_epsilon.csv')

# %% [markdown]
# # 3. Compute similarity

# %%
articles_df = articles_df.sort_values(by='publication_date')

# %%
t = 30
pairs_df = pd.DataFrame()
id_A = []
id_B = []
T = []
count = 0

for row in articles_df.iterrows():
    tweet_id_A = row[1]['tweet_id']
    date = row[1]['publication_date']
    date_df = articles_df[articles_df["publication_date"] >= (date)] 
    date_df = date_df[date_df["publication_date"] < (date + timedelta(days=t))] 
    for row_date in date_df.iterrows():
        tweet_id_B = row_date[1]['tweet_id']
        id_A.append(tweet_id_A)
        id_B.append(tweet_id_B)
        T.append(abs((date - row_date[1]['publication_date']).days))
        
    if count in [1000, 5000, 10000, 14000]:
        print(count)
        
    count += 1
# Out:
# 1000
# 5000
# 10000
# 14000

# %%
pairs_df = pd.DataFrame({'tweet_id_A':id_A, 'tweet_id_B':id_B, 'days':T})

# %%
# COMPUTE COSINE SIMILARITY OF TF-IDF FOR EACH PAIR OF ARTICLES
cosine_matrix = cosine_similarity_matrix(data, mapping_keys, pairs_df, mapping_tweets) 
pairs_df = add_similarity_column(pairs_df, mapping_keys, cosine_matrix, 'tf-idf')
# Out:
# ---GETTING NEWS
# ---STEM
# ---COMPUTE TF-IDF
# ---COMPUTE COSINE SIMILARITY MATRIX
# ERROR WITH:  1231420920851505153 1231578557568208896

# %%
pairs_df.head()

# %%
pairs_df.info()

# %%
cases_df = pairs_df[pairs_df['tf-idf']<0.35]

# %%
cases_df.info()

# %%
sources = list(cases_df['tweet_id_A'].values)
targets = list(cases_df['tweet_id_B'].values)
G = nx.Graph()
G.add_nodes_from(sources)
G.add_nodes_from(targets)
for i in range(len(sources)):
    G.add_edge(sources[i], targets[i])

# %%
cc_list = list(nx.connected_components(G))
cont = 0
cc_elements = []
cc_id = []
for cc in cc_list:
    for elem in cc:
        cc_elements.append(elem)
        cc_id.append(cont)
    cont += 1

# %%
connected_components_df = pd.DataFrame({'cluster_id':cc_id, 'tweet_id':cc_elements})

# %%
connected_components_df.info()

# %%
connected_components_df.head()

# %%
connected_components_df.to_csv('data/cases_df.csv', index=False)

# %%
len(list(nx.connected_components(G)))
